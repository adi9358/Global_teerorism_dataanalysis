# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv(r"C:\Users\adity\myself\terrorism_project.csv")

# %%
df
# Out:
#         Unnamed: 0       eventid  iyear         country_txt  \
# 0                0  197000000001   1970  Dominican Republic
# 1                1  197000000002   1970              Mexico
# 2                2  197001000001   1970         Philippines
# 3                3  197001000002   1970              Greece
# 4                4  197001000003   1970               Japan
# ...            ...           ...    ...                 ...
# 181686      181686  201712310022   2017             Somalia
# 181687      181687  201712310029   2017               Syria
# 181688      181688  201712310030   2017         Philippines
# 181689      181689  201712310031   2017               India
# 181690      181690  201712310032   2017         Philippines
#
#                        attacktype1_txt                targtype1_txt  \
# 0                        Assassination  Private Citizens & Property
# 1          Hostage Taking (Kidnapping)      Government (Diplomatic)
# ...

# %%
df = df[['eventid','iyear','country_txt','attacktype1_txt','targtype1_txt','gname','nkill','nwound','weaptype1_txt','ransomamt','propvalue','motive','region_txt','weapsubtype1_txt']]

# %%
df
# Out:
#              eventid  iyear         country_txt  \
# 0       197000000001   1970  Dominican Republic
# 1       197000000002   1970              Mexico
# 2       197001000001   1970         Philippines
# 3       197001000002   1970              Greece
# 4       197001000003   1970               Japan
# ...              ...    ...                 ...
# 181686  201712310022   2017             Somalia
# 181687  201712310029   2017               Syria
# 181688  201712310030   2017         Philippines
# 181689  201712310031   2017               India
# 181690  201712310032   2017         Philippines
#
#                        attacktype1_txt                targtype1_txt  \
# 0                        Assassination  Private Citizens & Property
# 1          Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                        Assassination          Journalists & Media
# 3                    Bombing/Explosion      Government (Diplomatic)
# ...

# %%
df.shape
# Out:
# (181691, 14)

# %%
##information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           181691 non-null  int64
#  1   iyear             181691 non-null  int64
#  2   country_txt       181691 non-null  object
#  3   attacktype1_txt   181691 non-null  object
#  4   targtype1_txt     181691 non-null  object
#  5   gname             181691 non-null  object
#  6   nkill             171378 non-null  float64
#  7   nwound            165380 non-null  float64
#  8   weaptype1_txt     181691 non-null  object
#  9   ransomamt         1350 non-null    float64
#  10  propvalue         38989 non-null   float64
#  11  motive            50561 non-null   object
#  12  region_txt        181691 non-null  object
#  13  weapsubtype1_txt  160923 non-null  object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 19.4+ MB

# %%
##checking for the null values
df.isnull().sum()
# Out:
# eventid                  0
# iyear                    0
# country_txt              0
# attacktype1_txt          0
# targtype1_txt            0
# gname                    0
# nkill                10313
# nwound               16311
# weaptype1_txt            0
# ransomamt           180341
# propvalue           142702
# motive              131130
# region_txt               0
# weapsubtype1_txt     20768
# dtype: int64

# %% [markdown]
# REGIONS SUFFERING MAXIMUM TERRORIST ATTACKS.

# %%
ui =df["region_txt"].value_counts()

# %%
ui
# Out:
# region_txt
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: count, dtype: int64

# %%
##Middle East & North Africa suffers maximum terrorist attcks ..

# %%
plt.figure(figsize=(12,8))
li=sns.barplot(x=ui.index,y=ui.values,hue=ui.index)
plt.xlabel("Countries")
plt.xticks(rotation=90)
plt.ylabel("Terrorists Attack")
plt.title("Top 15 countries most Terrorists Attack",color="purple")
for i in li.containers:
    plt.bar_label(i)

plt.gcf().set_facecolor("lightblue")
ax = li.axes
ax.set_facecolor("lightgreen")
plt.show()

# %% [markdown]
#  . TREND OF TERROSIST ATTACKS OF WORLD AND ALSO FOR INDIA.

# %%
year_trend = df["iyear"].value_counts()

# %%
year_trend
# Out:
# iyear
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: count, dtype: int64

# %%
##2014 was the year in which maximum terrorists attack occur..

# %%
plt.figure(figsize=(24,12))
bi =sns.barplot(x=year_trend.index,y=year_trend.values,color="black",width=0.9)
plt.xlabel("year")
plt.title("Attack Trends Over Years",color="blue",fontsize=15)
plt.xticks(rotation=90)
for i in bi.containers:
    plt.bar_label(i,label_type="edge",rotation=90,color="red")

# %%
india= df[df["country_txt"]=="India"]

# %%
india_trend = india["iyear"].value_counts()

# %%
india_trend
# Out:
# iyear
# 2016    1025
# 2017     966
# 2015     884
# 2014     860
# 2013     694
# 2009     672
# 2010     663
# 2011     645
# 2012     611
# 2008     534
# 1988     358
# 1990     349
# 1991     339
# 1989     324
# 1992     237
# 2001     234
# 1996     213
# 2003     196
# 1997     193
# 2002     184
# 2000     180
# 1995     179
# 2006     167
# 1987     166
# 1984     159
# 2007     149
# 2005     146
# 1999     112
# 2004     108
# 1994     107
# 1986      96
# 1998      61
# 1983      47
# 1985      39
# 1979      20
# 1981      16
# 1982      13
# 1980      10
# 1975       1
# 1977       1
# 1976       1
# 1972       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,18))
bi =sns.barplot(x=india_trend.index,y=india_trend.values,color="Blue",width=0.9)
plt.xlabel("year")
plt.title("Attack Trends Over Years in India",color="blue",fontsize=15)
plt.xticks(rotation=90)
for i in bi.containers:
    plt.bar_label(i,label_type="edge",rotation=90)

# %% [markdown]
# TOP 10 COUNTRIES IMPACTED BY TERROSISM .

# %%
top10countries = df["country_txt"].value_counts().head(10)

# %%
top10countries
# Out:
# country_txt
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: count, dtype: int64

# %%
## iraq suffers most attacks in the country list...

# %%
plt.figure(figsize=(12,8))
di = sns.barplot(x=top10countries.index,y=top10countries.values,hue=top10countries.index)
plt.xlabel("Countries")
plt.ylabel("Freuency of the Ataacks")
plt.title("Top 10 Countries Most Terrorists Attacks",color="black")

plt.gcf().set_facecolor("lightpink")
di.axes.set_facecolor("lightpink")
for i in di.containers:
    plt.bar_label(i,label_type="edge",color="purple")
plt.show()

# %% [markdown]
# TERRORIST ORGANIZATION RESPONSIBLE FOR MOST ATTACKS.

# %%
gi=df["gname"].value_counts()

# %%
gi.head(12)
# Out:
# gname
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Name: count, dtype: int64

# %%
print(f"Most Terrorists Organisation responsible for attacks is {gi.index[1]} with {gi.values[1]} Attacks ")
# Out:
# Most Terrorists Organisation responsible for attacks is Taliban with 7478 Attacks

# %%
print(f"Least Terrorists Organisation responsible for attacks is {gi.index[-1]} with {gi.values[-1]} Attack ")
# Out:
# Least Terrorists Organisation responsible for attacks is MANO-D with 1 Attack

# %%
plt.figure(figsize=(12,8))
plt.pie(gi.values[2:11],labels=gi.index[2:11],radius=1.7,autopct="%1.1f%%",labeldistance=1.1,pctdistance=0.6,shadow=True,textprops={"fontsize":15})

center_cicrle = plt.Circle((0,0),radius=1.1,fc="white")
fig=plt.gcf()
fig.gca().add_artist(center_cicrle)
plt.gcf().set_facecolor("lightpink")
plt.show()

# %% [markdown]
# Which terrorist organization has attacked the most and weapon used and their style of attack?

# %% [markdown]
# <h1/> Weapons Used by Talibans <h1/>

# %%
talibans = df[df["gname"]=="Taliban"]

# %%
talibans_weapons = talibans["weapsubtype1_txt"].value_counts()

# %%
talibans_weapons
# Out:
# weapsubtype1_txt
# Unknown Gun Type                             2549
# Unknown Explosive Type                        805
# Landmine                                      620
# Projectile (rockets, mortars, RPGs, etc.)     510
# Vehicle                                       485
# Suicide (carried bodily by human being)       332
# Arson/Fire                                    201
# Other Explosive Type                          151
# Remote Trigger                                135
# Automatic or Semi-Automatic Rifle              86
# Sticky Bomb                                    77
# Knife or Other Sharp Object                    64
# Grenade                                        42
# Rope or Other Strangling Device                23
# Pressure Trigger                               21
# Poisoning                                      19
# Handgun                                        14
# Hands, Feet, Fists                              6
# ...

# %%
print(f"Taliban Terrorists Organisation Most uses weapons for  attacks is {talibans_weapons.index[0]} with {talibans_weapons.values[0]} Attacks ")
# Out:
# Taliban Terrorists Organisation Most uses weapons for  attacks is Unknown Gun Type with 2549 Attacks

# %%
print(f"Taliban Terrorists Organisation Least uses weapons for  attacks is {talibans_weapons.index[-1]} with {talibans_weapons.values[-1]} Attacks ")
# Out:
# Taliban Terrorists Organisation Least uses weapons for  attacks is Blunt Object with 1 Attacks

# %%
plt.figure(figsize=(24,12))
plt.pie(talibans_weapons.values[1:10],labels=talibans_weapons.index[1:10],radius=1.7,autopct="%1.1f%%",labeldistance=1.1,pctdistance=0.55,shadow=True,textprops={"fontsize":18})

plt.title("Weapons used by Talibans for Attacks After Unknown GUN type",fontsize=23,loc="left",y=1.25)
center_cicrle = plt.Circle((0,0),radius=1.1,fc="white")
fig=plt.gcf()
fig.gca().add_artist(center_cicrle)
plt.gcf().set_facecolor("lightpink")
plt.show()

# %% [markdown]
# <h1> Preferred Style Attack of Taliban</h1>

# %%
prefered_attack = talibans["attacktype1_txt"].value_counts()

# %%
prefered_attack
# Out:
# attacktype1_txt
# Bombing/Explosion                      2866
# Armed Assault                          2125
# Unknown                                 966
# Hostage Taking (Kidnapping)             713
# Assassination                           508
# Facility/Infrastructure Attack          235
# Unarmed Assault                          33
# Hostage Taking (Barricade Incident)      19
# Hijacking                                13
# Name: count, dtype: int64

# %%
plt.figure(figsize=(24,12))
plt.pie(prefered_attack.values,labels=prefered_attack.index,radius=1.7,autopct="%1.1f%%",labeldistance=1.1,pctdistance=0.59,shadow=True,textprops={"fontsize":18})

plt.title("Prefered Style of Attack Of Talibans",fontsize=23,loc="center",y=1.25)
center_cicrle = plt.Circle((0,0),radius=1.1,fc="white")
fig=plt.gcf()
fig.gca().add_artist(center_cicrle)
plt.gcf().set_facecolor("lightpink")
plt.show()

# %%
df["loss(in B)"] = (df["propvalue"] + df["ransomamt"])/1000000000

# %%
df
# Out:
#              eventid  iyear         country_txt  \
# 0       197000000001   1970  Dominican Republic
# 1       197000000002   1970              Mexico
# 2       197001000001   1970         Philippines
# 3       197001000002   1970              Greece
# 4       197001000003   1970               Japan
# ...              ...    ...                 ...
# 181686  201712310022   2017             Somalia
# 181687  201712310029   2017               Syria
# 181688  201712310030   2017         Philippines
# 181689  201712310031   2017               India
# 181690  201712310032   2017         Philippines
#
#                        attacktype1_txt                targtype1_txt  \
# 0                        Assassination  Private Citizens & Property
# 1          Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                        Assassination          Journalists & Media
# 3                    Bombing/Explosion      Government (Diplomatic)
# ...

# %%
propvalue=df.groupby('iyear')['propvalue'].sum()
ransomvalue=df.groupby('iyear')['ransomamt'].sum()
total_sum=(propvalue+ransomvalue)/100000000
plt.figure(figsize=(14,7))
total_sum.plot(kind='line',fontsize=12,color='green')
plt.title('Monetary loss due to Terrorism in USD$',fontsize=14)
plt.ylabel('Damage in billions',fontsize=14)
plt.xlabel('Year',fontsize=14)
plt.xticks(list(total_sum.index),rotation=90)
plt.show()

# %% [markdown]
# ##<b> Inference:-
# ### * In the year 1992 due to terrorism activities, there are heavy monetary value lost which is more than $25 Billion USD.

# %% [markdown]
# ## . Which terror organization has attacked the most in India?

# %%
india_most_attack = india["gname"].value_counts()

# %%
india_most_attack
# Out:
# gname
# Unknown                                           4263
# Communist Party of India - Maoist (CPI-Maoist)    1877
# Maoists                                           1396
# Sikh Extremists                                    710
# United Liberation Front of Assam (ULFA)            357
#                                                   ...
# Akhilesh Singh Gang                                  1
# Ananda Marga                                         1
# Al-Hamas Mujahideen                                  1
# Achik National Volunteer Council (ANVC)              1
# Ansar Ghazwat-ul-Hind                                1
# Name: count, Length: 301, dtype: int64

# %%
print(f" Terrorists Organisation Most attacks is {india_most_attack.index[1]}")
# Out:
#  Terrorists Organisation Most attacks is Communist Party of India - Maoist (CPI-Maoist)

# %%
plt.figure(figsize=(24,12))
plt.pie(india_most_attack.values[1:10],labels=india_most_attack.index[1:10],radius=1.7,autopct="%1.1f%%",labeldistance=1.1,pctdistance=0.55,shadow=True,textprops={"fontsize":18})

plt.title(" Top 10 terrorists group in india",fontsize=23,loc="center",y=1.25)
center_cicrle = plt.Circle((0,0),radius=1.1,fc="white")
fig=plt.gcf()
fig.gca().add_artist(center_cicrle)
plt.gcf().set_facecolor("lightpink")
plt.show()

# %% [markdown]
# <h1>
#     MOST ACTIVE TERRORIST ORGANIZATIONS IN LAST 5 YEARS IN THE WORLD .
# </h1>

# %%
last_5_years = df[df["iyear"]>2012]

# %%
last_5_years_active=last_5_years["gname"].value_counts()

# %%
last_5_years_active
# Out:
# gname
# Unknown                                           33501
# Islamic State of Iraq and the Levant (ISIL)        5613
# Taliban                                            5018
# Al-Shabaab                                         2727
# Boko Haram                                         1842
#                                                   ...
# Popular Front for Recovery (FPR)                      1
# Jaish as-Saiyouf (Army of Swords)                     1
# Partido Marxista-Leninista ng Pilipinas (PMLP)        1
# Jaish Usama                                           1
# Al-Sawaiq Brigade                                     1
# Name: count, Length: 842, dtype: int64

# %%
plt.figure(figsize=(12,8))

si = sns.barplot(x=last_5_years_active.index[0:11],y=last_5_years_active.values[0:11],hue=last_5_years_active.index[0:11])
plt.title("last 5 years Active terrorists group that performs terrorists attack",color="brown")
plt.xlabel("Terroists Group")
plt.xticks(rotation=90)
for i in si.containers:
    plt.bar_label(i)
plt.show()

# %% [markdown]
# <h2>Unknown Terrorists Group perform 33501 attacks<h2/>.<br>after that (ISIL) perform  second highest attack in world with 5613 attacks

# %%
last_5_years_attack_inindia = india[india["iyear"]>2012]

# %%
last_5_years_attack_inindia["gname"].value_counts()
# Out:
# gname
# Unknown                                           1652
# Maoists                                           1163
# Communist Party of India - Maoist (CPI-Maoist)     407
# Hizbul Mujahideen (HM)                             108
# Garo National Liberation Army                      105
#                                                   ...
# United Jihad Council                                 1
# Achik Matgrik Army (AMA)                             1
# United Reformation Protest of India                  1
# Kuki Independent Organization (KIO/KIA)              1
# Ansar Ghazwat-ul-Hind                                1
# Name: count, Length: 135, dtype: int64

# %%
plt.figure(figsize=(12,8))

si = sns.barplot(x=last_5_years_attack_inindia["gname"].value_counts().index[0:11],y=last_5_years_attack_inindia["gname"].value_counts().values[0:11],palette="viridis")
plt.title("last 5 years Active terrorists group that performs terrorists attack in India",color="brown")
plt.xlabel("Terroists Group")
plt.xticks(rotation=90)
for i in si.containers:
    plt.bar_label(i)
plt.show()

# %% [markdown]
# <h2>Unknown Terrorists Group perform 1652 attacks<h2/>.<br>after that Maoists perform  second highest attack in india with 1162 attacks in last 5 years till 2017.

# %% [markdown]
# <h1>
#     Thankyou
# </h1>
